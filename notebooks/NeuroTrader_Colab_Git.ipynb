# %% [markdown]
# # 🧠 NeuroTrader Ultimate: Git Workflow Edition
#
# This notebook pulls your latest code from GitHub and runs the training script.
# **Benefit:** No more incompatible environments or copy-pasting code!

# %% [markdown]
# ## 1. Connect Google Drive ☁️
# We need Drive to save logs and models.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Clone Repository 🐙
# Replace `YOUR_GITHUB_REPO_URL` with your actual repository link.

# %%
import os

# ⚠️ REPLACE THIS WITH YOUR REPO URL
REPO_URL = "https://github.com/MaDoHee33/NeuroTrader.git"

if not os.path.exists("NeuroTrader"):
    # !git clone $REPO_URL
else:
    # %cd NeuroTrader
    # !git pull
    # %cd ..

# %% [markdown]
# ## 3. Install Dependencies 📦
# We install exactly what's permitted in `requirements_colab.txt`.

# %%
# %cd NeuroTrader
# !pip install -r requirements_colab.txt --force-reinstall

# %% [markdown]
# ## 4. Run Training 🏃‍♂️

# %%
# Ensure data is uploaded to Drive or local folder first!
# We force CD to ensure we are in the correct directory even after restarts
# %cd /content/NeuroTrader
# !python src/brain/train_ppo.py

# %%
# %load_ext tensorboard
# %tensorboard --logdir "/content/drive/MyDrive/NeuroTrader_Workspace/logs"
